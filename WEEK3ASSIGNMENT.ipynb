# %%
# 1.READ THE DATASET TO PYTHON ENVIRONMENT
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('iris.xls')
df

# %% [markdown]
# 2.DISPLAY THE COLUMNS IN DATASET

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3.CALCULATE THE MEAN OF EACH COLUMN OF THE DATASET

# %%
col_mean=df[cols].mean(axis=0)
col_mean=col_mean.round(2)
col_mean
# Out:
# SL    5.84
# SW    3.05
# PL    3.76
# PW    1.20
# dtype: float64

# %% [markdown]
# 4.CHECK FOR THE NULL VALUES PRESENT IN THE DATASET

# %%
df.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
#  6.PERFORM MEANINGFULL ISUALIZATIONS USING THE DATASET. BRING ATLEAST 3 VISUALIZATIONS

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.hist(df['SL'],rwidth=.8,color='BLACK')
plt.title('Histogram of SL')
plt.xlabel('SL')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.scatter(df['SW'],df['SL'],c='blue',s=10,marker='^')
plt.title('Plot of SL Vs SW')
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
import matplotlib.pyplot as plt
plt.plot(df['PL'])
plt.title('line plot of PL')
plt.xlabel('PL')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
